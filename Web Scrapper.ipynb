# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/59.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------- ----- 51.2/59.7 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 798.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 2.6 MB/s eta 0:00:05
#     --------------------------------------- 0.2/11.6 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/11.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.6 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.6 MB 2.4 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/11.6 MB 2.5 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/11.6 MB 2.7 MB/s eta 0:00:04
# ...

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import pandas as pd
import smtplib

# %%
url= "https://www.amazon.eg/-/en/ArtWorld-Atomic-Habits-Proven-Habits/dp/B07VQKP8ZJ/ref=sr_1_5?crid=2H7XSGO70UI6G&dib=eyJ2IjoiMSJ9.p9AhjwbMkg3ameFEylyPEN19bD34GbM3fQABSPzAh2W4D_Ub9r7AuiYU4TdLEXHizsu_6vnollbka3iBmaE-RRFMiMbfjSS-Hhp0j4Iyw-KtjjZe9dF987BgRD0Gj_IMSzXkXc50VcUPGyYrqVD9DBI4PuYFW5EiNGOP_fqAtxIH2pI82maZ4qcNapFhWrGjb1tvtad8t4wVm0yCHL-rqjr0_GprSODsaKP2H0PtD2G6WZkwSrOH_LGYOuGPhqeg2pPO-LA7c3mU-2o-cXVg2d28YAquv-MbspaWFgsM9GQ.3kMCsiNIKSO2e0osOTaD1P-Qp0mYIbXUbxFOAkb3xhw&dib_tag=se&keywords=books&qid=1728298207&sprefix=boo%2Caps%2C406&sr=8-5"
headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"}
page = requests.get(url, headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(),'html.parser')
title= soup2.find(id='productTitle').get_text()
price= soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()
price=price.strip()[:9]
price=price.strip()[4:]
title=title.strip()
print(title,price)
# Out:
# ArtWorld [James Clear]-Atomic Habits- an Easy & Proven Way to Build Good Habits & Break Bad Ones (HB) 88.00

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2024-10-07

# %%
import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv("AmazonWebScraperDataset.csv")
df.head()
# Out:
#                                                Title  Price        Date
# 0  ArtWorld [James Clear]-Atomic Habits- an Easy ...   88.0  2024-10-07

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    server.ehlo()
    server.login('abdelrahmanabushady5@gmail.com', 'saek wenm gsey fppn')

    subject = "The Book you want is below $15! Now is your chance to buy!"
    body = "Abdelrahman, This is the moment we have been waiting for."

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'abdelrahmanabushady5@gmail.com',
        'abdelrahmanabushady5@gmail.com',  # Add the recipient email address here
        msg
    )
    server.quit()

send_mail()
